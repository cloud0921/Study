# %%
from matplotlib import pyplot as plt
plt.plot([10,20,30,40])
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.title('plotting')
plt.plot([10,20,30,40])
plt.show()

# %%
import matplotlib.pyplot as plt

a= [1,2,3,4]
b= [12,43,25,15]
plt.plot(a,b)
plt.show()
